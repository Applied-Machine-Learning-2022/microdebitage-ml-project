# %%
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
ARCH00164_TM_Residential = pd.read_excel("EXP-00001-Master.xlsx")

not_included = ['Id', 'Filter0','Filter1', 'Filter2','Filter3', 'Filter4', 'Filter5', 'Filter6', 'hash', 'Img Id', 'Curvature', 'Transparency', 'Angularity']
filtered = [x for x in ARCH00164_TM_Residential.columns if x not in not_included]
ARCH164_filterd = ARCH00164_TM_Residential[filtered]

# %%
# Out:
#            Da      Dp  FWidth FLength FThickness ELength EThickness  EWidth  \
# 0          mm      mm      mm      mm         mm      mm         mm      mm
# 1       8.239    9.95   7.553  11.859       6.87   11.24      6.554   7.102
# 2       7.458   9.413   7.125  12.474      6.326  12.592      6.018   6.718
# 3       7.503  11.113   7.955  13.472      5.912  11.638      6.046   7.404
# 4      11.256  13.044  12.528  16.425      5.625  15.719      5.289  11.606
# ...       ...     ...     ...     ...        ...     ...        ...     ...
# 48562   0.351   0.458   0.315   0.655      0.144   0.617      0.145   0.294
# 48563   0.277   0.328   0.308   0.485      0.141   0.468      0.133   0.295
# 48564   0.148   0.153    0.14   0.165       0.14   0.161      0.137   0.137
# 48565   0.448   0.709   0.507   1.247      0.139   1.317      0.109   0.474
# 48566   0.142    0.15   0.132   0.171      0.132   0.157      0.131   0.131
#
# ...
